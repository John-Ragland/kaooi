# %%
# Test files

# %%
import xarray as xr
import obspy
import os

# %%
fn = '/datadrive/kauai/transmissions/ooi_bb_tc/LJ01A/20230827T000000.nc'

ds = xr.open_dataset(fn)

# %%
ds['LJ01A'].plot()

# %%
url = 'https://rawdata-west.oceanobservatories.org/files/RS01SLBS/LJ01A/09-HYDBBA102/2023/08/27/OO-HYVM1--YDH-2023-08-27T00:00:00.000000Z.mseed'
os.system(f'wget {url}')

# %%
st = obspy.read('OO-HYVM1--YDH-2023-08-27T00:00:00.000000Z.mseed')

# %%
st.merge()
# Out:
# 1 Trace(s) in Stream:
# OO.HYVM1..YDH | 2023-08-27T00:00:00.000000Z - 2023-08-27T00:00:00.249984Z | 64000.0 Hz, 16000 samples
